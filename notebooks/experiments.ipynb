# %% [markdown]
# Todo: phyiscs simulation aus plot 2d separat, weil es gleich für 3d gebraucht werden kann. Es muss nur die telemetry und orbital mechanics anhand der neuen 3d vektoren aus physics simulation angepasst werden. Es gibt dann einmal telemetry und mechanics für 3d und einmal für 2d
#
# Falsch.
